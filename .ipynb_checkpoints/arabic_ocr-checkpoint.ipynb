# %% [markdown]
# # Optical Character Recognition of Arabic Characters
#
# Classifiying Arabic characters. For more details please visit [this link](https://www.kaggle.com/mloey1/ahdd1)

# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### Loading training dataset

# %%
# load training data
x_train = pd.read_csv('./dataset/csvTrainImages 13440x1024.csv')
print("Training images")
x_train.head()

# load training labels
y_train = pd.read_csv('./dataset/csvTrainLabel 13440x1.csv')
print("Training labels")
y_train.head()

# convert x_train dataframe to numpy ndarray and transpose each image using swapaxes.
x_train = x_train.values.reshape([-1,32,32]).swapaxes(1,2)

# convert y_train dataframe to numpy ndarray and remove all extra dimensions.
y_train = y_train.values.squeeze()
# Out:
# Training images
# Training labels

# %% [markdown]
# ### Loading test dataset

# %%
valid_test_split = 0.5

# load test data
x_test = pd.read_csv('./dataset/csvTestImages 3360x1024.csv')
x_test.head()
x_test = x_test.values.reshape([-1,32,32]).swapaxes(1,2)

# load test labels
y_test = pd.read_csv('./dataset/csvTestLabel 3360x1.csv')
y_test.head()
y_test = y_test.values.squeeze()

# %% [markdown]
# ### Creating validation and test splits of the test set

# %%
m_test = y_test.shape[0]
x_val = x_test[ : int(m_test * valid_test_split) ]
x_test = x_test[ int(m_test * valid_test_split) : ]

y_val = y_test[ : int(m_test * valid_test_split) ]
y_test = y_test[ int(m_test * valid_test_split) : ]

print("x_train shape:", x_train.shape)
print("x_val shape:", x_val.shape)
print("x_test shape:", x_test.shape)

print("y_train shape:", y_train.shape)
print("y_val shape:", y_val.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (13439, 32, 32)
# x_val shape: (1679, 32, 32)
# x_test shape: (1680, 32, 32)
# y_train shape: (13439,)
# y_val shape: (1679,)
# y_test shape: (1680,)

# %%
fig = plt.figure(0, figsize=(10,10))
indices = np.random.randint(0, y_train.shape[0], size=25)


for i, idx in enumerate(indices):
    plt.subplot(5,5,i+1)
    plt.imshow(x_train[idx], cmap='gray')
    plt.title(str(y_train[idx]))
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# ### Preprcoessing

# %%
x_train = x_train / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# %%
x_train = x_train[:,:,:,np.newaxis]
print(x_train.shape)
# Out:
# (13439, 32, 32, 1)

# %%
x_val = x_val[:,:,:,np.newaxis]
print(x_val.shape)
x_test = x_test[:,:,:,np.newaxis]
print(x_test.shape)
# Out:
# (1679, 32, 32, 1)
# (1680, 32, 32, 1)

# %%
from sklearn.preprocessing import OneHotEncoder

one_hot = OneHotEncoder()
y_train = one_hot.fit_transform(y_train[:, None]).toarray()
y_val = one_hot.fit_transform(y_val[:, None]).toarray()
y_test = one_hot.fit_transform(y_test[:, None]).toarray()

print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (13439, 28)
# (1679, 28)
# (1680, 28)

# %% [markdown]
# ### Building the classification model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, GlobalAveragePooling2D, BatchNormalization, Dropout
# Out:
# Using TensorFlow backend.

# %%
classifier = Sequential()
classifier.add(Conv2D(16, 5, strides=1, padding='valid', activation='relu', input_shape=[32, 32, 1]))
# classifier.add(BatchNormalization(axis=2))

classifier.add(Conv2D(32, 2, strides=2, padding='valid', activation='relu'))
classifier.add(BatchNormalization(axis=3))

classifier.add(Conv2D(64, 5, strides=1, padding='valid', activation='relu'))
classifier.add(BatchNormalization(axis=3))

classifier.add(Conv2D(128, 2, strides=2, padding='valid', activation='relu'))
classifier.add(BatchNormalization(axis=3))

classifier.add(GlobalAveragePooling2D())

classifier.add(Dropout(rate=0.4))
classifier.add(Dense(128, activation='relu'))
classifier.add(BatchNormalization(axis=1))

classifier.add(Dropout(rate=0.3))
classifier.add(Dense(28, activation='softmax'))

classifier.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
classifier.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_35 (Conv2D)           (None, 28, 28, 16)        416
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 14, 14, 32)        2080
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 10, 10, 64)        51264
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 10, 10, 64)        256
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 5, 5, 128)         32896
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 5, 5, 128)         512
# _________________________________________________________________
# global_average_pooling2d_9 ( (None, 128)               0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 28)                3612
# =================================================================
# Total params: 108,188.0
# Trainable params: 107,484.0
# Non-trainable params: 704.0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
# training
from keras.callbacks import ModelCheckpoint
chkpt = ModelCheckpoint('arabic_ocr_best_weights.md5', verbose=0, save_best_only=True)

history = classifier.fit(x_train,
                           y_train,
                           batch_size=256,
                           epochs=50,
                           verbose=2,
                           validation_data=(x_val, y_val),
                           callbacks=[chkpt])
# Out:
# Train on 13439 samples, validate on 1679 samples
# Epoch 1/50
# 3s - loss: 2.7714 - acc: 0.2244 - val_loss: 3.3555 - val_acc: 0.0357
# Epoch 2/50
# 1s - loss: 1.5737 - acc: 0.4833 - val_loss: 3.7641 - val_acc: 0.0363
# Epoch 3/50
# 1s - loss: 1.0542 - acc: 0.6505 - val_loss: 4.5790 - val_acc: 0.0631
# Epoch 4/50
# 1s - loss: 0.7527 - acc: 0.7572 - val_loss: 6.2472 - val_acc: 0.0357
# Epoch 5/50
# 1s - loss: 0.5845 - acc: 0.8114 - val_loss: 8.3274 - val_acc: 0.0530
# Epoch 6/50
# 1s - loss: 0.4638 - acc: 0.8570 - val_loss: 10.4364 - val_acc: 0.0631
# Epoch 7/50
# 1s - loss: 0.3804 - acc: 0.8812 - val_loss: 11.4719 - val_acc: 0.0459
# Epoch 8/50
# 1s - loss: 0.3133 - acc: 0.9059 - val_loss: 12.4504 - val_acc: 0.0405
# Epoch 9/50
# 1s - loss: 0.2699 - acc: 0.9222 - val_loss: 10.9739 - val_acc: 0.0488
# Epoch 10/50
# 1s - loss: 0.2322 - acc: 0.9301 - val_loss: 10.2176 - val_acc: 0.0625
# Epoch 11/50
# 1s - loss: 0.2027 - acc: 0.9391 - val_loss: 6.6790 - val_acc: 0.1340
# Epoch 12/50
# 1s - loss: 0.1798 - acc: 0.9477 - val_loss: 3.0545 - val_acc: 0.3961
# Epoch 13/50
# 1s - loss: 0.1591 - acc: 0.9526 - val_loss: 1.0927 - val_acc: 0.6599
# Epoch 14/50
# 1s - loss: 0.1391 - acc: 0.9591 - val_loss: 0.6635 - val_acc: 0.7796
# Epoch 15/50
# 1s - loss: 0.1228 - acc: 0.9658 - val_loss: 0.4200 - val_acc: 0.8529
# Epoch 16/50
# 1s - loss: 0.1186 - acc: 0.9656 - val_loss: 0.2306 - val_acc: 0.9232
# Epoch 17/50
# 1s - loss: 0.1109 - acc: 0.9664 - val_loss: 0.2802 - val_acc: 0.9077
# Epoch 18/50
# 1s - loss: 0.0954 - acc: 0.9720 - val_loss: 0.1863 - val_acc: 0.9387
# Epoch 19/50
# 1s - loss: 0.0811 - acc: 0.9771 - val_loss: 0.2271 - val_acc: 0.9369
# Epoch 20/50
# 1s - loss: 0.0704 - acc: 0.9807 - val_loss: 0.3994 - val_acc: 0.8672
# Epoch 21/50
# 1s - loss: 0.0768 - acc: 0.9777 - val_loss: 0.2089 - val_acc: 0.9404
# Epoch 22/50
# 1s - loss: 0.0657 - acc: 0.9812 - val_loss: 0.2307 - val_acc: 0.9357
# Epoch 23/50
# 1s - loss: 0.0625 - acc: 0.9824 - val_loss: 0.1992 - val_acc: 0.9440
# Epoch 24/50
# 1s - loss: 0.0546 - acc: 0.9847 - val_loss: 0.2743 - val_acc: 0.9285
# Epoch 25/50
# 1s - loss: 0.0541 - acc: 0.9849 - val_loss: 0.2170 - val_acc: 0.9381
# Epoch 26/50
# 1s - loss: 0.0532 - acc: 0.9845 - val_loss: 0.2251 - val_acc: 0.9381
# Epoch 27/50
# 1s - loss: 0.0487 - acc: 0.9864 - val_loss: 0.2024 - val_acc: 0.9500
# Epoch 28/50
# 1s - loss: 0.0405 - acc: 0.9894 - val_loss: 0.3086 - val_acc: 0.9297
# Epoch 29/50
# 1s - loss: 0.0426 - acc: 0.9870 - val_loss: 0.2136 - val_acc: 0.9351
# Epoch 30/50
# 1s - loss: 0.0374 - acc: 0.9902 - val_loss: 0.2869 - val_acc: 0.9369
# Epoch 31/50
# 1s - loss: 0.0387 - acc: 0.9886 - val_loss: 0.6403 - val_acc: 0.8130
# Epoch 32/50
# 1s - loss: 0.0341 - acc: 0.9907 - val_loss: 1.4487 - val_acc: 0.6861
# Epoch 33/50
# 1s - loss: 0.0371 - acc: 0.9897 - val_loss: 0.1691 - val_acc: 0.9583
# Epoch 34/50
# 1s - loss: 0.0373 - acc: 0.9893 - val_loss: 0.3098 - val_acc: 0.9256
# Epoch 35/50
# 1s - loss: 0.0331 - acc: 0.9903 - val_loss: 0.3505 - val_acc: 0.9160
# Epoch 36/50
# 1s - loss: 0.0325 - acc: 0.9904 - val_loss: 1.7527 - val_acc: 0.6301
# Epoch 37/50
# 1s - loss: 0.0288 - acc: 0.9914 - val_loss: 0.2046 - val_acc: 0.9494
# Epoch 38/50
# 1s - loss: 0.0283 - acc: 0.9924 - val_loss: 0.2976 - val_acc: 0.9238
# Epoch 39/50
# 1s - loss: 0.0219 - acc: 0.9952 - val_loss: 0.3214 - val_acc: 0.8993
# Epoch 40/50
# 1s - loss: 0.0242 - acc: 0.9935 - val_loss: 0.4162 - val_acc: 0.9148
# Epoch 41/50
# 1s - loss: 0.0264 - acc: 0.9926 - val_loss: 0.3695 - val_acc: 0.9083
# Epoch 42/50
# 1s - loss: 0.0243 - acc: 0.9936 - val_loss: 0.1957 - val_acc: 0.9529
# Epoch 43/50
# 1s - loss: 0.0232 - acc: 0.9938 - val_loss: 0.3149 - val_acc: 0.9154
# Epoch 44/50
# 1s - loss: 0.0277 - acc: 0.9917 - val_loss: 0.3868 - val_acc: 0.9119
# Epoch 45/50
# 1s - loss: 0.0251 - acc: 0.9925 - val_loss: 0.2118 - val_acc: 0.9494
# Epoch 46/50
# 1s - loss: 0.0239 - acc: 0.9932 - val_loss: 0.2348 - val_acc: 0.9446
# Epoch 47/50
# 1s - loss: 0.0228 - acc: 0.9934 - val_loss: 0.3033 - val_acc: 0.9267
# Epoch 48/50
# 1s - loss: 0.0211 - acc: 0.9935 - val_loss: 0.2545 - val_acc: 0.9351
# Epoch 49/50
# 1s - loss: 0.0198 - acc: 0.9940 - val_loss: 0.2657 - val_acc: 0.9404
# Epoch 50/50
# 1s - loss: 0.0205 - acc: 0.9940 - val_loss: 0.2023 - val_acc: 0.9506

# %%
ev = classifier.evaluate(x_test, y_test)
print(classifier.metrics_names[0], ev[0])
print(classifier.metrics_names[1], ev[1])
# Out:
# 1600/1680 [===========================>..] - ETA: 0sloss 0.184600791123
# acc 0.955952380952

# %% [markdown]
# ### Plotting Accuracy VS Epochs

# %%
val_acc = history.history['val_acc']
val_loss = history.history['val_loss']
fig = plt.figure(1, figsize=(10,5))
plt.plot(val_acc)
# plt.plot(val_loss)
plt.legend(['Accuracy', 'Loss'])
plt.show()

# %% [markdown]
# ### Plotting random test samples with their predicted labels and true labels

# %%
fig = plt.figure(0, figsize=(20,20))
indices = np.random.randint(0, y_test.shape[0], size=49)
y_pred = np.argmax(classifier.predict(x_test), axis=1)

for i, idx in enumerate(indices):
    plt.subplot(7,7,i+1)
    plt.imshow(x_test[idx][:,:,0], cmap='gray')
    plt.title("Pred: {} - Label: {}".format(y_pred[idx], np.argmax(y_test[idx])))
    plt.xticks([])
    plt.yticks([])
plt.show()
